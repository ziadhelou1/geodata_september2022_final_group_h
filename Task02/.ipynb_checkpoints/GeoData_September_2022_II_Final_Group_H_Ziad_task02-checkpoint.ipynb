# %% [markdown]
# ## 2. DWD Precipitation Measurements in North Rhine-Westphalia (NRW): Create a Movie with QGIS Temporal Controller

# %% [markdown]
# ##### Spatio-Temporal Precipitation Anmination using PostGIS together with QGIS Temporal Controller
#
# Produce a rainfall video over a 7-day period in 2021 that covers the heavy rains that led to the catastrophic flooding. The animation should cover all DWD stations in NRW with hourly precipitation. Create a point layer in QGIS showing the stations in NRW with time dependent precipitation rate data (mm per hour) in the attribute table. This layer has to come from a PostGIS view, which joins the two tables with 1) static station info including coordinates and 2) time dependent precipitation rates. Use the QGIS Temporal Controller to produce an animation.

# %% [markdown]
# #### Sub-Task 2.1:

# %% [markdown]
# Create and fill your own geodatabase
# Create and fill your own geodatabase with DWD precipitation station data as well as hourly precipitation time series. Follow the Jupyter Notebook tutorial of geo0930_PostGIS_Insert_DWD_Stations_and_TS (main notebook geo0930_PostGIS_DWD_Stations_and_TS_V002.ipynb) together with the respective YouTube tutorial here
#
# (Remark: The general opengeo repository is under construction. I am using it to reorganize my teaching material independent from specific courses. It will be filled step by step.)
#
# The last part of the video tutorial (from March 2021) is meanwhile outdated, because it explains how to produce an animation based on the QGIS TimaManager plugin. The TimeManager plugin is deprecated! The new way is to use the QGIS Temporal Controller, which is integrated in recent QGIS versions. I have no video on that, yet.
#
# The following video shows an example of a precipitation animation generated with the QGIS TimeManager. It is meant to give you an idea about the activity.

# %%
# The topic of interest
topic_dir = "/hourly/precipitation/historical/"
print("Subdirectory on FTP Server:", topic_dir)
# Out:
# Subdirectory on FTP Server: /hourly/precipitation/historical/

# %% [markdown]
# ## Local Directories

# %%
#local_ftp_dir         = "../data/original/DWD/"      # Local directory to store local ftp data copies, the local data source or input data. 
local_ftp_dir         = "data/original/DWD/"      # Local directory to store local ftp data copies, the local data source or input data. 
local_ftp_station_dir = local_ftp_dir + topic_dir # Local directory where local station info is located
local_ftp_ts_dir      = local_ftp_dir + topic_dir # Local directory where time series downloaded from ftp are located

#local_generated_dir   = "../data/generated/DWD/" # The generated of derived data in contrast to local_ftp_dir
local_generated_dir   = "data/generated/DWD/" # The generated of derived data in contrast to local_ftp_dir
local_station_dir     = local_generated_dir + topic_dir # Derived station data, i.e. the CSV file
local_ts_merged_dir   = local_generated_dir + topic_dir # Parallel merged time series, wide data frame with one TS per column
local_ts_appended_dir = local_generated_dir + topic_dir # Serially appended time series, long data frame for QGIS TimeManager Plugin

# %%
import os
os.makedirs(local_ftp_dir,exist_ok = True) # it does not complain if the dir already exists.
os.makedirs(local_ftp_station_dir,exist_ok = True)
os.makedirs(local_ftp_ts_dir,exist_ok = True)

os.makedirs(local_generated_dir,exist_ok = True)
os.makedirs(local_station_dir,exist_ok = True)
os.makedirs(local_ts_merged_dir,exist_ok = True)
os.makedirs(local_ts_appended_dir,exist_ok = True)

# %%
print(local_ftp_dir)
print(local_ftp_station_dir)
print(local_ftp_ts_dir)
print()
print(local_generated_dir)
print(local_station_dir)
print(local_ts_merged_dir)
print(local_ts_appended_dir)
# Out:
# data/original/DWD/
# data/original/DWD//hourly/precipitation/historical/
# data/original/DWD//hourly/precipitation/historical/
#
# data/generated/DWD/
# data/generated/DWD//hourly/precipitation/historical/
# data/generated/DWD//hourly/precipitation/historical/
# data/generated/DWD//hourly/precipitation/historical/

# %% [markdown]
# ## FTP Connection

# %%
server = "opendata.dwd.de"
user   = "anonymous"
passwd = ""

# %% [markdown]
# ### FTP Directory Definition and Station Description Filename Pattern

# %%
# This is the search pattern common to ALL station description file names 
station_desc_pattern = "_Beschreibung_Stationen.txt"

# Below this directory tree node all climate data are stored.
ftp_climate_data_dir = "/climate_environment/CDC/observations_germany/climate/"

# The absolute ftp directory with the data (topic) of concern
ftp_dir =  ftp_climate_data_dir + topic_dir
print("Absolte FTP directory path with data of concern:", ftp_dir)
# Out:
# Absolte FTP directory path with data of concern: /climate_environment/CDC/observations_germany/climate//hourly/precipitation/historical/

# %% [markdown]
# ### FTP Connect

# %%
import ftplib
ftp = ftplib.FTP(server)
res = ftp.login(user=user, passwd = passwd)
print(res)
# Out:
# 230 Login successful.

# %%
ret = ftp.cwd(".")

# %% [markdown]
# ### FTP Grab File Function

# %%
def grabFile(ftpfullname,localfullname):
    try:
        ret = ftp.cwd(".") # A dummy action to chack the connection and to provoke an exception if necessary.
        localfile = open(localfullname, 'wb')
        ftp.retrbinary('RETR ' + ftpfullname, localfile.write, 1024)
        localfile.close()
    
    except ftplib.error_perm:
        print("FTP ERROR. Operation not permitted. File not found?")

    except ftplib.error_temp:
        print("FTP ERROR. Timeout.")

    except ConnectionAbortedError:
        print("FTP ERROR. Connection aborted.")

# %% [markdown]
# ## Generate Pandas Dataframe from FTP Directory Listing

# %%
import pandas as pd
import os

def gen_df_from_ftp_dir_listing(ftp, ftpdir):
    lines = []
    flist = []
    try:    
        res = ftp.retrlines("LIST "+ftpdir, lines.append)
    except:
        print("Error: ftp.retrlines() failed. ftp timeout? Reconnect!")
        return
        
    if len(lines) == 0:
        print("Error: ftp dir is empty")
        return
    
    for line in lines:
#        print(line)
        [ftype, fsize, fname] = [line[0:1], int(line[31:42]), line[56:]]
#        itemlist = [line[0:1], int(line[31:42]), line[56:]]
#        flist.append(itemlist)
        
        fext = os.path.splitext(fname)[-1]
        
        if fext == ".zip":
            station_id = int(fname.split("_")[2])
        else:
            station_id = -1 
        
        flist.append([station_id, fname, fext, fsize, ftype])
        
        

    df_ftpdir = pd.DataFrame(flist,columns=["station_id", "name", "ext", "size", "type"])
    return(df_ftpdir)

# %%
df_ftpdir = gen_df_from_ftp_dir_listing(ftp, ftp_dir)

# %%
df_ftpdir.head(10)
# Out:
#    station_id                                               name   ext  \
# 0          -1  BESCHREIBUNG_obsgermany_climate_hourly_precipi...  .pdf
# 1          -1  DESCRIPTION_obsgermany_climate_hourly_precipit...  .pdf
# 2          -1         RR_Stundenwerte_Beschreibung_Stationen.txt  .txt
# 3           3   stundenwerte_RR_00003_19950901_20110401_hist.zip  .zip
# 4          20   stundenwerte_RR_00020_20040814_20211231_hist.zip  .zip
# 5          44   stundenwerte_RR_00044_20070401_20211231_hist.zip  .zip
# 6          53   stundenwerte_RR_00053_20051001_20211231_hist.zip  .zip
# 7          71   stundenwerte_RR_00071_20041022_20200101_hist.zip  .zip
# 8          73   stundenwerte_RR_00073_20070401_20211231_hist.zip  .zip
# 9          78   stundenwerte_RR_00078_20041101_20211231_hist.zip  .zip
#
#      size type
# 0  166317    -
# 1  161348    -
# 2  310685    -
# 3  418905    -
# 4  456263    -
# 5  378416    -
# 6  409591    -
# 7  402406    -
# 8  380526    -
# 9  445888    -

# %% [markdown]
# ### Dataframe with TS Zip Files

# %%
df_zips = df_ftpdir[df_ftpdir["ext"]==".zip"]
df_zips.set_index("station_id", inplace = True)
df_zips.head(10)
# Out:
#                                                         name   ext    size  \
# station_id
# 3           stundenwerte_RR_00003_19950901_20110401_hist.zip  .zip  418905
# 20          stundenwerte_RR_00020_20040814_20211231_hist.zip  .zip  456263
# 44          stundenwerte_RR_00044_20070401_20211231_hist.zip  .zip  378416
# 53          stundenwerte_RR_00053_20051001_20211231_hist.zip  .zip  409591
# 71          stundenwerte_RR_00071_20041022_20200101_hist.zip  .zip  402406
# 73          stundenwerte_RR_00073_20070401_20211231_hist.zip  .zip  380526
# 78          stundenwerte_RR_00078_20041101_20211231_hist.zip  .zip  445888
# 87          stundenwerte_RR_00087_20050201_20211231_hist.zip  .zip  426930
# 91          stundenwerte_RR_00091_20040901_20211231_hist.zip  .zip  443441
# 96          stundenwerte_RR_00096_20190409_20211231_hist.zip  .zip   79249
#
#            type
# station_id
# 3             -
# 20            -
# 44            -
# 53            -
# 71            -
# 73            -
# 78            -
# 87            -
# 91            -
# 96            -

# %% [markdown]
# ## Download the Station Description File

# %%
station_fname = df_ftpdir[df_ftpdir['name'].str.contains(station_desc_pattern)]["name"].values[0]
print(station_fname)
# Out:
# RR_Stundenwerte_Beschreibung_Stationen.txt

# %%
print("grabFile: ")
print("From: " + ftp_dir + station_fname)
print("To:   " + local_ftp_station_dir + station_fname)
grabFile(ftp_dir + station_fname, local_ftp_station_dir + station_fname)
# Out:
# grabFile:
# From: /climate_environment/CDC/observations_germany/climate//hourly/precipitation/historical/RR_Stundenwerte_Beschreibung_Stationen.txt
# To:   data/original/DWD//hourly/precipitation/historical/RR_Stundenwerte_Beschreibung_Stationen.txt

# %%
# extract column names. They are in German (de)
# We have to use codecs because of difficulties with character encoding (German Umlaute)
import codecs

def station_desc_txt_to_csv(txtfile, csvfile):
    file = codecs.open(txtfile, "r", encoding="latin1")
    r = file.readline()
    file.close()
    colnames_de = r.split()
    colnames_de
    
    translate = \
    {'Stations_id':'station_id',
     'von_datum':'date_from',
     'bis_datum':'date_to',
     'Stationshoehe':'altitude',
     'geoBreite': 'latitude',
     'geoLaenge': 'longitude',
     'Stationsname':'name',
     'Bundesland':'state'}
    
    colnames_en = [translate[h] for h in colnames_de]
    
    # Skip the first two rows and set the column names.
    df = pd.read_fwf(\
        txtfile, skiprows=2, names=colnames_en, \
        parse_dates=["date_from","date_to"], index_col = 0, \
        encoding="latin1")
    
    # write csv
    df.to_csv(csvfile, sep = ";")
    return(df)

# %%
basename = os.path.splitext(station_fname)[0]
df_stations = station_desc_txt_to_csv(local_ftp_station_dir + station_fname, local_station_dir + basename + ".csv")
df_stations.head()
# Out:
#             date_from    date_to  altitude  latitude  longitude  \
# station_id
# 3          1995-09-01 2011-04-01       202   50.7827     6.0941
# 20         2004-08-14 2022-09-04       432   48.9219     9.9129
# 29         2006-01-10 2022-09-04       260   49.7175    10.9101
# 44         2007-04-01 2022-09-04        44   52.9336     8.2370
# 46         2006-01-03 2022-09-04       325   48.9450    12.4639
#
#                                 name                state
# station_id
# 3                             Aachen  Nordrhein-Westfalen
# 20          Abtsgmünd-Untergröningen    Baden-Württemberg
# 29            Adelsdorf (Kläranlage)               Bayern
# 44                      Großenkneten        Niedersachsen
# 46                          Aholfing               Bayern

# %% [markdown]
# ### Select Stations Located in North Rhine-Westphalia from Station Description Dataframe

# %%
# Create variable with TRUE if state is Nordrhein-Westfalen
isNRW = (df_stations['state'] == "Nordrhein-Westfalen").values

# Create variable with TRUE if date_to is latest date (indicates operation up to now)
isOperational = df_stations['date_to'] == df_stations.date_to.max()

# select on both conditions
dfNRW = df_stations[isNRW & isOperational]

print(f"Stations located in North Rhine-Westphalia and still active till the end of the historical data: \n{list(dfNRW)}")
# Out:
# Stations located in North Rhine-Westphalia and still active till the end of the historical data:
# ['date_from', 'date_to', 'altitude', 'latitude', 'longitude', 'name', 'state']

# %%
df_stations.loc[station_ids_selected].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [106], in <cell line: 1>()
# ----> 1 df_stations.loc[station_ids_selected].head()
#
# File ~\anaconda3\anaconda\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\anaconda\lib\site-packages\pandas\core\indexing.py:1189, in _LocIndexer._getitem_axis(self, key, axis)
#    1186 if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
# -> 1189         raise ValueError("Cannot index with multidimensional key")
#    1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#
# ValueError: Cannot index with multidimensional key

# %%
# Add the names of the zip files only to a list. 
local_zip_list = []

for station_id in station_ids_selected:
    try:
        fname = df_zips["name"][station_id]
        print(fname)
        grabFile(ftp_dir + fname, local_ftp_ts_dir + fname)
        local_zip_list.append(fname)
    except:
        print("WARNING: TS file for key %d not found in FTP directory." % station_id)
# Out:
# stundenwerte_RR_00216_20041001_20211231_hist.zip
# stundenwerte_RR_00389_20091101_20211231_hist.zip
# stundenwerte_RR_00390_20040701_20211231_hist.zip
# stundenwerte_RR_00554_19950901_20211231_hist.zip
# stundenwerte_RR_00603_19990303_20211231_hist.zip
# stundenwerte_RR_00613_20041101_20211231_hist.zip
# stundenwerte_RR_00617_20040601_20211231_hist.zip
# stundenwerte_RR_00644_20050101_20211231_hist.zip
# stundenwerte_RR_00796_20041101_20211231_hist.zip
# stundenwerte_RR_00871_20050801_20211231_hist.zip
# stundenwerte_RR_00902_20061001_20211231_hist.zip
# stundenwerte_RR_00934_20041001_20211231_hist.zip
# stundenwerte_RR_00989_20050201_20211231_hist.zip
# stundenwerte_RR_01024_20060801_20211231_hist.zip
# stundenwerte_RR_01046_20041001_20211231_hist.zip
# stundenwerte_RR_01078_19950901_20211231_hist.zip
# stundenwerte_RR_01241_20061201_20211231_hist.zip
# stundenwerte_RR_01246_20150801_20211231_hist.zip
# stundenwerte_RR_01300_20040601_20211231_hist.zip
# stundenwerte_RR_01303_19950901_20211231_hist.zip
# stundenwerte_RR_01327_20040801_20211231_hist.zip
# stundenwerte_RR_01590_20030701_20211231_hist.zip
# stundenwerte_RR_01595_20121001_20211231_hist.zip
# stundenwerte_RR_01766_19950901_20211231_hist.zip
# stundenwerte_RR_02027_20060601_20211231_hist.zip
# stundenwerte_RR_02110_20030105_20211231_hist.zip
# stundenwerte_RR_02254_20050601_20211231_hist.zip
# stundenwerte_RR_02473_20041201_20211231_hist.zip
# stundenwerte_RR_02483_19951012_20211231_hist.zip
# stundenwerte_RR_02497_20040801_20211231_hist.zip
# stundenwerte_RR_02629_20040701_20211231_hist.zip
# stundenwerte_RR_02667_19950901_20211231_hist.zip
# stundenwerte_RR_02810_20061201_20211231_hist.zip
# stundenwerte_RR_02947_20061001_20211231_hist.zip
# stundenwerte_RR_02968_20081201_20211231_hist.zip
# stundenwerte_RR_02999_20040701_20211231_hist.zip
# stundenwerte_RR_03028_19950901_20211231_hist.zip
# stundenwerte_RR_03031_20040701_20211231_hist.zip
# stundenwerte_RR_03081_20071201_20211231_hist.zip
# stundenwerte_RR_03098_19950901_20211231_hist.zip
# stundenwerte_RR_03215_20070601_20211231_hist.zip
# stundenwerte_RR_03321_20050701_20211231_hist.zip
# WARNING: TS file for key 3328 not found in FTP directory.
# stundenwerte_RR_03339_20060901_20211231_hist.zip
# stundenwerte_RR_03499_20060701_20211231_hist.zip
# stundenwerte_RR_03540_20041101_20211231_hist.zip
# stundenwerte_RR_03591_20040601_20211231_hist.zip
# stundenwerte_RR_03795_20041201_20211231_hist.zip
# stundenwerte_RR_03913_20040701_20211231_hist.zip
# stundenwerte_RR_04063_20030701_20211231_hist.zip
# stundenwerte_RR_04127_20050101_20211231_hist.zip
# stundenwerte_RR_04150_20051201_20211231_hist.zip
# stundenwerte_RR_04313_20040801_20211231_hist.zip
# stundenwerte_RR_04368_20041001_20211231_hist.zip
# stundenwerte_RR_04371_19950901_20211231_hist.zip
# stundenwerte_RR_04400_20040801_20211231_hist.zip
# stundenwerte_RR_04488_20060801_20211231_hist.zip
# stundenwerte_RR_04741_20041201_20211231_hist.zip
# stundenwerte_RR_04849_20050601_20211231_hist.zip
# stundenwerte_RR_05064_20041201_20211231_hist.zip
# stundenwerte_RR_05347_19950901_20211231_hist.zip
# stundenwerte_RR_05360_20070701_20211231_hist.zip
# stundenwerte_RR_05468_20060701_20201001_hist.zip
# stundenwerte_RR_05480_20030910_20211231_hist.zip
# stundenwerte_RR_05513_20050901_20211231_hist.zip
# stundenwerte_RR_05619_20041201_20211231_hist.zip
# stundenwerte_RR_05699_20041101_20211231_hist.zip
# stundenwerte_RR_05717_20060901_20211231_hist.zip
# stundenwerte_RR_05733_20050501_20211231_hist.zip
# WARNING: TS file for key 6041 not found in FTP directory.
# WARNING: TS file for key 6042 not found in FTP directory.
# WARNING: TS file for key 6043 not found in FTP directory.
# WARNING: TS file for key 6044 not found in FTP directory.
# WARNING: TS file for key 6045 not found in FTP directory.
# WARNING: TS file for key 6046 not found in FTP directory.
# WARNING: TS file for key 6047 not found in FTP directory.
# WARNING: TS file for key 6048 not found in FTP directory.
# WARNING: TS file for key 6049 not found in FTP directory.
# WARNING: TS file for key 6050 not found in FTP directory.
# WARNING: TS file for key 6051 not found in FTP directory.
# WARNING: TS file for key 6052 not found in FTP directory.
# WARNING: TS file for key 6053 not found in FTP directory.
# WARNING: TS file for key 6054 not found in FTP directory.
# WARNING: TS file for key 6055 not found in FTP directory.
# WARNING: TS file for key 6057 not found in FTP directory.
# WARNING: TS file for key 6058 not found in FTP directory.
# WARNING: TS file for key 6059 not found in FTP directory.
# WARNING: TS file for key 6060 not found in FTP directory.
# WARNING: TS file for key 6061 not found in FTP directory.
# WARNING: TS file for key 6064 not found in FTP directory.
# WARNING: TS file for key 6067 not found in FTP directory.
# stundenwerte_RR_06197_20001013_20211231_hist.zip
# stundenwerte_RR_06264_20040601_20211231_hist.zip
# stundenwerte_RR_06276_20041101_20191102_hist.zip
# stundenwerte_RR_06313_20041201_20211231_hist.zip
# stundenwerte_RR_06337_20040801_20211231_hist.zip
# stundenwerte_RR_07106_20060901_20211231_hist.zip
# stundenwerte_RR_07330_20051001_20211231_hist.zip
# stundenwerte_RR_07344_20060601_20211231_hist.zip
# stundenwerte_RR_07374_20060301_20211231_hist.zip
# stundenwerte_RR_07378_20060701_20211231_hist.zip
# stundenwerte_RR_13669_20070901_20211231_hist.zip
# stundenwerte_RR_13670_20070601_20211231_hist.zip
# stundenwerte_RR_13671_20071201_20211231_hist.zip
# stundenwerte_RR_13696_20071201_20211231_hist.zip
# stundenwerte_RR_13700_20080501_20211231_hist.zip
# stundenwerte_RR_13713_20071101_20211231_hist.zip
# WARNING: TS file for key 14096 not found in FTP directory.
# WARNING: TS file for key 14142 not found in FTP directory.
# WARNING: TS file for key 14143 not found in FTP directory.
# WARNING: TS file for key 14144 not found in FTP directory.
# WARNING: TS file for key 14145 not found in FTP directory.
# WARNING: TS file for key 14146 not found in FTP directory.
# WARNING: TS file for key 14147 not found in FTP directory.
# WARNING: TS file for key 14148 not found in FTP directory.
# WARNING: TS file for key 14149 not found in FTP directory.
# WARNING: TS file for key 14150 not found in FTP directory.
# WARNING: TS file for key 14151 not found in FTP directory.
# WARNING: TS file for key 14152 not found in FTP directory.
# WARNING: TS file for key 14153 not found in FTP directory.
# WARNING: TS file for key 14154 not found in FTP directory.
# WARNING: TS file for key 14155 not found in FTP directory.
# WARNING: TS file for key 14156 not found in FTP directory.
# WARNING: TS file for key 14158 not found in FTP directory.
# WARNING: TS file for key 14159 not found in FTP directory.
# WARNING: TS file for key 14164 not found in FTP directory.
# WARNING: TS file for key 14165 not found in FTP directory.
# WARNING: TS file for key 14166 not found in FTP directory.
# WARNING: TS file for key 14167 not found in FTP directory.
# WARNING: TS file for key 14168 not found in FTP directory.
# WARNING: TS file for key 14169 not found in FTP directory.
# WARNING: TS file for key 14170 not found in FTP directory.
# WARNING: TS file for key 14171 not found in FTP directory.
# WARNING: TS file for key 14172 not found in FTP directory.
# WARNING: TS file for key 14173 not found in FTP directory.
# WARNING: TS file for key 14174 not found in FTP directory.
# WARNING: TS file for key 14175 not found in FTP directory.
# WARNING: TS file for key 14176 not found in FTP directory.
# WARNING: TS file for key 14177 not found in FTP directory.
# WARNING: TS file for key 14178 not found in FTP directory.
# WARNING: TS file for key 14179 not found in FTP directory.
# WARNING: TS file for key 14180 not found in FTP directory.
# WARNING: TS file for key 14181 not found in FTP directory.
# WARNING: TS file for key 14182 not found in FTP directory.
# WARNING: TS file for key 14183 not found in FTP directory.
# WARNING: TS file for key 14184 not found in FTP directory.
# WARNING: TS file for key 14185 not found in FTP directory.
# WARNING: TS file for key 14186 not found in FTP directory.
# WARNING: TS file for key 14187 not found in FTP directory.
# stundenwerte_RR_15000_20110401_20211231_hist.zip
# WARNING: TS file for key 19451 not found in FTP directory.
# WARNING: TS file for key 19452 not found in FTP directory.
# WARNING: TS file for key 19453 not found in FTP directory.
# WARNING: TS file for key 19454 not found in FTP directory.
# WARNING: TS file for key 19455 not found in FTP directory.
# WARNING: TS file for key 19456 not found in FTP directory.
# WARNING: TS file for key 19457 not found in FTP directory.
# WARNING: TS file for key 19458 not found in FTP directory.
# WARNING: TS file for key 19459 not found in FTP directory.
# WARNING: TS file for key 19460 not found in FTP directory.
# WARNING: TS file for key 19461 not found in FTP directory.
# WARNING: TS file for key 19462 not found in FTP directory.
# WARNING: TS file for key 19463 not found in FTP directory.
# WARNING: TS file for key 19464 not found in FTP directory.
# WARNING: TS file for key 19465 not found in FTP directory.
# WARNING: TS file for key 19467 not found in FTP directory.
# WARNING: TS file for key 19469 not found in FTP directory.

# %%
print(len(local_zip_list))
# Out:
# 85

# %% [markdown]
# ## Selected Period for Time Series in Data Frames
#
# These parameters are used to limit the time period of the series added to the Pandas data frames.
# <br>To select all dates in the series you can set a very broad interval, e.g.

# %%
date_from = '2021-07-12 00:00:00'
date_to   = '2021-07-19 00:00:00'
#working on hourly time frame during 7 days only when the flood occured in NRW in July 2021

# %% [markdown]
# ## Join (Merge) the Time Series Columns
#
# The goal is to create a data frame with column oriented time series. Each column contuins a time series for one station. Column name is the station number.

# %% [markdown]
# ### Precipitation Time Series Data (text file) to Data Frame
# Read a text file with precipitation time series (CSV file) and make it a data frame. <br>
# Only add measuerments which lie within the given time period.

# %%
import datetime as dt

# %%
def prec_ts_to_df(fname, date_from='2021-07-12 00:00:00', date_to='2021-07-12 00:00:00'):
    import datetime as dt
    
    dateparse = lambda dates: [dt.datetime.strptime(str(d), '%Y%m%d%H') for d in dates]

    df = pd.read_csv(fname, delimiter=";", encoding="utf8", index_col="MESS_DATUM",
                     parse_dates = ["MESS_DATUM"], date_parser = dateparse, na_values = [-999.0, -999])

    # Attention: Selecting df with given dates may lead to empty result!
    df = df[(df.index >= date_from) & (df.index <= date_to)]
    
    # Code inspired by: https://medium.com/@chaimgluck1/working-with-pandas-fixing-messy-column-names-42a54a6659cd
    # Column headers: remove leading blanks (strip), replace " " with "_", and convert to lower case.

    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_', regex=False).str.replace('(', '', regex=False).str.replace(')', '', regex=False)
    df.index.name = df.index.name.strip().lower().replace(' ', '_').replace('(', '').replace(')', '')
    return(df)

# %% [markdown]
# ### Climate Time Series Data (text file) to Data Frame
# The KL data format for annual temperatures differs significantly from the RR format for hourly precipitation.
#
# Tha hourly data uses a unique time stamp in hourly resolution `[MESS_DATUM]`, e.g. ['2021071410'], as time reference for the measurements.

# %%
def kl_ts_to_df(fname, date_from='2021-07-12', date_to='2021-07-19'):
    import datetime as dt
    
    dateparse = lambda dates: [dt.datetime.strptime(str(d), '%Y%m%d%H') for d in dates]

    df = pd.read_csv(fname, delimiter=";", encoding="utf8", index_col="MESS_DATUM", date_parser = dateparse, na_values = [-999.0, -999])

    # Attention: Selecting df with given dates may lead to empty result!
    df = df[(df.index >= date_from) & (df.index <= date_to)]
    
    # Code inspired by: https://medium.com/@chaimgluck1/working-with-pandas-fixing-messy-column-names-42a54a6659cd
    # Column headers: remove leading blanks (strip), replace " " with "_", and convert to lower case.

    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_', regex=False).str.replace('(', '', regex=False).str.replace(')', '', regex=False)
    df.index.name = df.index.name.strip().lower().replace(' ', '_').replace('(', '').replace(')', '')
    return(df)

# %% [markdown]
# ### Merge Columnwise

# %%
from zipfile import ZipFile
def ts_merge(date_from='2021-07-12 00:00:00', date_to='2021-07-19 00:00:00'):
    # Very compact code.
    df = pd.DataFrame()
    for elt in local_zip_list:
        ffname = local_ftp_ts_dir + elt
        print("Zip archive: " + ffname)
        with ZipFile(ffname) as myzip:
            # read the time series data from the file starting with "produkt"
            prodfilename = [elt for elt in myzip.namelist() if elt.split("_")[0]=="produkt"][0] 
            print("Extract product file: %s" % prodfilename)
            print()
            with myzip.open(prodfilename) as myfile:
                dftmp = kl_ts_to_df(myfile, date_from, date_to)

                #if len(dftmp) > 0: # Check if cropped df is empty, i.e. no values in given period.
                 #   s = dftmp["R1"].rename(dftmp["stations_id"][0]).to_frame()
                  #  df = pd.merge(df, s, left_index=True, right_index=True, how='outer')
                #else:
                 #   print("WARNING: data file", prodfilename, "does not contain data for given period.")


    df.index.rename(name = "time", inplace = True)
    return(df)

# %%
df_merged_ts = ts_merge(date_from, date_to)
# Out:
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00216_20041001_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20211231_00216.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00389_20091101_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20091101_20211231_00389.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00390_20040701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20211231_00390.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00554_19950901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20211231_00554.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00603_19990303_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19990303_20211231_00603.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00613_20041101_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20211231_00613.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00617_20040601_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20211231_00617.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00644_20050101_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20050101_20211231_00644.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00796_20041101_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20211231_00796.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00871_20050801_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20050801_20211231_00871.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00902_20061001_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20061001_20211231_00902.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00934_20041001_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20211231_00934.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00989_20050201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20050201_20211231_00989.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01024_20060801_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20060801_20211231_01024.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01046_20041001_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20211231_01046.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01078_19950901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20211231_01078.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01241_20061201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20061201_20211231_01241.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01246_20150801_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20150801_20211231_01246.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01300_20040601_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20211231_01300.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01303_19950901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20211231_01303.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01327_20040801_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20211231_01327.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01590_20030701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20030701_20211231_01590.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01595_20121001_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20121001_20211231_01595.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01766_19950901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20211231_01766.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02027_20060601_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20060601_20211231_02027.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02110_20030105_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20030105_20211231_02110.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02254_20050601_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20050601_20211231_02254.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02473_20041201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20211231_02473.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02483_19951012_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19951012_20211231_02483.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02497_20040801_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20211231_02497.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02629_20040701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20211231_02629.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02667_19950901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20211231_02667.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02810_20061201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20061201_20211231_02810.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02947_20061001_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20061001_20211231_02947.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02968_20081201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20081201_20211231_02968.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02999_20040701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20211231_02999.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03028_19950901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20211231_03028.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03031_20040701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20211231_03031.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03081_20071201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20071201_20211231_03081.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03098_19950901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20211231_03098.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03215_20070601_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20070601_20211231_03215.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03321_20050701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20050701_20211231_03321.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03339_20060901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20060901_20211231_03339.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03499_20060701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20060701_20211231_03499.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03540_20041101_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20211231_03540.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03591_20040601_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20211231_03591.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03795_20041201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20211231_03795.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03913_20040701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20211231_03913.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04063_20030701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20030701_20211231_04063.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04127_20050101_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20050101_20211231_04127.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04150_20051201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20051201_20211231_04150.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04313_20040801_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20211231_04313.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04368_20041001_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20211231_04368.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04371_19950901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20211231_04371.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04400_20040801_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20211231_04400.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04488_20060801_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20060801_20211231_04488.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04741_20041201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20211231_04741.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04849_20050601_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20050601_20211231_04849.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05064_20041201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20211231_05064.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05347_19950901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20211231_05347.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05360_20070701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20070701_20211231_05360.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05468_20060701_20201001_hist.zip
# Extract product file: produkt_rr_stunde_20060701_20201001_05468.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05480_20030910_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20030910_20211231_05480.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05513_20050901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20050901_20211231_05513.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05619_20041201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20211231_05619.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05699_20041101_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20211231_05699.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05717_20060901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20060901_20211231_05717.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05733_20050501_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20050501_20211231_05733.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_06197_20001013_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20001013_20211231_06197.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_06264_20040601_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20211231_06264.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_06276_20041101_20191102_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20191102_06276.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_06313_20041201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20211231_06313.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_06337_20040801_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20211231_06337.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_07106_20060901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20060901_20211231_07106.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_07330_20051001_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20051001_20211231_07330.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_07344_20060601_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20060601_20211231_07344.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_07374_20060301_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20060301_20211231_07374.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_07378_20060701_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20060701_20211231_07378.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13669_20070901_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20070901_20211231_13669.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13670_20070601_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20070601_20211231_13670.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13671_20071201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20071201_20211231_13671.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13696_20071201_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20071201_20211231_13696.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13700_20080501_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20080501_20211231_13700.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13713_20071101_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20071101_20211231_13713.txt
#
# Zip archive: data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_15000_20110401_20211231_hist.zip
# Extract product file: produkt_rr_stunde_20110401_20211231_15000.txt

# %%
df_plt = df_stations [(( df_stations['name'].str.contains("Meinerzhagen-Redlendorf")) |
                       (df_stations['name'].str.contains("Aachen-Orsbach")))]
df_plt
# Out:
#             date_from    date_to  altitude  latitude  longitude  \
# station_id
# 13713      2007-11-01 2022-09-04       386   51.0899     7.6289
# 15000      2011-04-01 2022-09-04       231   50.7983     6.0244
#
#                                name                state
# station_id
# 13713       Meinerzhagen-Redlendorf  Nordrhein-Westfalen
# 15000                Aachen-Orsbach  Nordrhein-Westfalen
